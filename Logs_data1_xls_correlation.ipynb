# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/deep/blob/main/Logs_data1_xls_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch

# %%
import pandas as pd

# %%
import torch
from torch import nn

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %%
CAD_path="/content/logs_CAD_2024_1.xlsx"

# %%
data = pd.read_excel("/content/logs_CAD_2024_1.xlsx")

# %%
display(pd.DataFrame(data))
# Out:
#                timestamp  user_id  tool_id  log_count  lesson  day_part
# 0     15/04/24, 11:37:03    26861   233243      3.000       0         1
# 1     15/04/24, 11:37:03    26861   233243      0.000       0         1
# 2     15/04/24, 11:37:03    26861   233243      0.000       0         1
# 3     15/04/24, 11:30:50    26861     2949      1.000       0         1
# 4     15/04/24, 11:30:37    26861   244208      3.000       0         1
# ...                  ...      ...      ...        ...     ...       ...
# 6091   1/02/24, 20:00:42    29349     2949      0.000       0         3
# 6092  29/01/24, 19:00:53    29349     2949      0.000       0         3
# 6093  29/01/24, 19:00:52    29349     2949      0.000       0         3
# 6094  29/01/24, 19:00:52    29349     2949      0.000       0         3
# 6095  29/01/24, 19:00:52    29349     2949      0.000       0         3
#
# [6096 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['user_id'].plot(kind='hist', bins=20, title='user_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['tool_id'].plot(kind='hist', bins=20, title='tool_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['log_count'].plot(kind='hist', bins=20, title='log_count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_43['lesson'].plot(kind='hist', bins=20, title='lesson')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44.plot(kind='scatter', x='user_id', y='tool_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_45.plot(kind='scatter', x='tool_id', y='log_count', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_46.plot(kind='scatter', x='log_count', y='lesson', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47.plot(kind='scatter', x='lesson', y='day_part', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['user_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_48.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('user_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['tool_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_49.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('tool_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['log_count']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_50.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('log_count')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['lesson']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_51.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('lesson')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52['user_id'].plot(kind='line', figsize=(8, 4), title='user_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53['tool_id'].plot(kind='line', figsize=(8, 4), title='tool_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54['log_count'].plot(kind='line', figsize=(8, 4), title='log_count')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55['lesson'].plot(kind='line', figsize=(8, 4), title='lesson')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Settings

# %%
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
pd.options.display.float_format = '{:.3f}'.format

# %% [markdown]
# Feature Engineering

# %%
df = pd.read_excel("/content/logs_CAD_2024_1.xlsx")
test_df = pd.read_excel("/content/logs_CAD_2024_1.xlsx")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6096 entries, 0 to 6095
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  6096 non-null   object
#  1   user_id    6096 non-null   int64
#  2   tool_id    6096 non-null   int64
#  3   log_count  6095 non-null   float64
#  4   lesson     6096 non-null   int64
#  5   day_part   6096 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 285.9+ KB

# %%
df.sample(n=5)
# Out:
#       log_count  lesson  day_part  user_id_20004  user_id_20010  \
# 301       0.037       0         2          False          False
# 3114      0.037       1         1           True          False
# 3694      0.000       1         3          False          False
# 3270      0.074       1         1          False          False
# 3225      0.037       1         1          False          False
#
#       user_id_20503  user_id_20544  user_id_20700  user_id_20789  \
# 301           False          False          False          False
# 3114          False          False          False          False
# 3694          False           True          False          False
# 3270          False           True          False          False
# 3225          False          False          False          False
#
#       user_id_20804  ...  user_id_23558  user_id_26861  user_id_29084  \
# 301           False  ...          False          False          False
# 3114          False  ...          False          False          False
# 3694          False  ...          False          False          False
# 3270          False  ...          False          False          False
# 3225          False  ...          False          False          False
#
#       user_id_29133  user_id_29292  user_id_29340  user_id_29349  \
# 301           False          False          False          False
# 3114          False          False          False          False
# 3694          False          False          False          False
# 3270          False          False          False          False
# 3225          False          False          False           True
#
#       user_id_29350  user_id_29598  user_id_29723
# 301           False          False           True
# 3114          False          False          False
# 3694          False          False          False
# 3270          False          False          False
# 3225          False          False          False
#
# [5 rows x 21 columns]

# %%
def feature_engineering(df): #feature engineering function

    return df

# %%
df = feature_engineering(df)

# %% [markdown]
# Remove columns I no longer need

# %%
df = df.drop(['tool_id', 'timestamp'], axis=1)

# %%
df.sample(n=5)
# Out:
#       log_count  lesson  day_part  user_id_20004  user_id_20010  \
# 2557      0.111       0         2          False          False
# 4415      0.037       0         2          False          False
# 2827      0.074       0         4          False          False
# 5747      0.037       1         3          False          False
# 3464      0.074       0         5          False          False
#
#       user_id_20503  user_id_20544  user_id_20700  user_id_20789  \
# 2557          False           True          False          False
# 4415          False          False           True          False
# 2827          False          False          False          False
# 5747          False           True          False          False
# 3464          False          False          False          False
#
#       user_id_20804  ...  user_id_23558  user_id_26861  user_id_29084  \
# 2557          False  ...          False          False          False
# 4415          False  ...          False          False          False
# 2827          False  ...          False          False          False
# 5747          False  ...          False          False          False
# 3464          False  ...          False          False          False
#
#       user_id_29133  user_id_29292  user_id_29340  user_id_29349  \
# 2557          False          False          False          False
# 4415          False          False          False          False
# 2827          False          False          False          False
# 5747          False          False          False          False
# 3464          False          False          False           True
#
#       user_id_29350  user_id_29598  user_id_29723
# 2557          False          False          False
# 4415          False          False          False
# 2827           True          False          False
# 5747          False          False          False
# 3464          False          False          False
#
# [5 rows x 21 columns]

# %% [markdown]
# Data Cleaning

# %%
df.isna().sum()
# Out:
# user_id      0
# log_count    1
# lesson       0
# day_part     0
# dtype: int64

# %% [markdown]
# Min-max scaling
#
# Normalization

# %%
def scale_min_max(df, col_name, xmin, xmax):
    df[col_name] = (df[col_name] - xmin) / (xmax - xmin)
    return df

train_age_min = df['log_count'].min()
train_age_max = df['log_count'].max()
df = scale_min_max(df, 'log_count', train_age_min, train_age_max)

df['log_count'].describe()
# Out:
# count   6095.000
# mean       0.036
# std        0.064
# min        0.000
# 25%        0.000
# 50%        0.000
# 75%        0.037
# max        1.000
# Name: log_count, dtype: float64

# %% [markdown]
# Dummy variables addition:

# %%
def add_dummies(df, cols):
    df = pd.get_dummies(df, columns=cols)
    return df

cols = ['user_id']
df = add_dummies(df, cols)

print(df.columns, '\n', len(df.columns))
# Out:
# Index(['log_count', 'lesson', 'day_part', 'user_id_20004', 'user_id_20010',
#        'user_id_20503', 'user_id_20544', 'user_id_20700', 'user_id_20789',
#        'user_id_20804', 'user_id_23030', 'user_id_23558', 'user_id_26861',
#        'user_id_29084', 'user_id_29133', 'user_id_29292', 'user_id_29340',
#        'user_id_29349', 'user_id_29350', 'user_id_29598', 'user_id_29723'],
#       dtype='object')
#  21

# %% [markdown]
# Data is procecced

# %%
test_proc = (test_df.pipe(feature_engineering) #Apply the same data processing steps to the test set
                    .drop(['tool_id', 'timestamp'], axis=1)
                    .pipe(scale_min_max, 'log_count', train_age_min, train_age_max)
                    .pipe(add_dummies, cols)
)

test_proc.sample(6)
# Out:
#       log_count  lesson  day_part  user_id_20004  user_id_20010  \
# 1145      0.000       0         3           True          False
# 4877      0.000       1         1          False          False
# 3968      0.037       1         3          False          False
# 4157      0.111       0         2          False          False
# 63        0.000       0         1          False          False
# 2122      0.037       0         0          False          False
#
#       user_id_20503  user_id_20544  user_id_20700  user_id_20789  \
# 1145          False          False          False          False
# 4877          False          False          False          False
# 3968          False           True          False          False
# 4157          False          False          False          False
# 63            False          False          False          False
# 2122          False          False          False          False
#
#       user_id_20804  ...  user_id_23558  user_id_26861  user_id_29084  \
# 1145          False  ...          False          False          False
# 4877          False  ...          False          False           True
# 3968          False  ...          False          False          False
# 4157          False  ...          False           True          False
# 63            False  ...          False           True          False
# 2122          False  ...          False          False          False
#
#       user_id_29133  user_id_29292  user_id_29340  user_id_29349  \
# 1145          False          False          False          False
# 4877          False          False          False          False
# 3968          False          False          False          False
# 4157          False          False          False          False
# 63            False          False          False          False
# 2122          False           True          False          False
#
#       user_id_29350  user_id_29598  user_id_29723
# 1145          False          False          False
# 4877          False          False          False
# 3968          False          False          False
# 4157          False          False          False
# 63            False          False          False
# 2122          False          False          False
#
# [6 rows x 21 columns]

# %%
def divide_df(all_data):
    # Returns divided dfs of training and test set
    return all_data.loc[:16], all_data.loc[16:].drop(['Grade'], axis=1)

df_train = pd.read_excel("/content/logs_CAD_2024_1.xlsx")
df_test = pd.read_excel("/content/logs_CAD_2024_1.xlsx")


df_train.name = 'Training Set'
df_test.name = 'Test Set'


dfs = [df_train, df_test]

print('Number of Training Examples = {}'.format(df_train.shape[0]))
print('Number of Test Examples = {}\n'.format(df_test.shape[0]))
print('Training X Shape = {}'.format(df_train.shape))
print('Training y Shape = {}\n'.format(df_train['user_id'].shape[0]))
print('Test X Shape = {}'.format(df_test.shape))
print('Test y Shape = {}\n'.format(df_test.shape[0]))
print(df_train.columns)
print(df_test.columns)
# Out:
# Number of Training Examples = 6096
# Number of Test Examples = 6096
#
# Training X Shape = (6096, 6)
# Training y Shape = 6096
#
# Test X Shape = (6096, 6)
# Test y Shape = 6096
#
# Index(['timestamp', 'user_id', 'tool_id', 'log_count', 'lesson', 'day_part'], dtype='object')
# Index(['timestamp', 'user_id', 'tool_id', 'log_count', 'lesson', 'day_part'], dtype='object')

# %%
print(df_train.info())
df_train.sample(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6096 entries, 0 to 6095
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  6096 non-null   object
#  1   user_id    6096 non-null   int64
#  2   tool_id    6096 non-null   int64
#  3   log_count  6095 non-null   float64
#  4   lesson     6096 non-null   int64
#  5   day_part   6096 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 285.9+ KB
# None
#                timestamp  user_id  tool_id  log_count  lesson  day_part
# 4366  19/02/24, 12:02:28    20789   233219      1.000       0         2
# 1789  28/03/24, 08:40:38    29133   233257      2.000       1         1
# 4830  15/02/24, 08:51:42    20503   233223      2.000       1         1

# %%
# Ensure 'timestamp' column is dropped from both training and test datasets
df_train_cleaned = df_train.drop(['timestamp'], axis=1)
df_test_cleaned = df_test.drop(['timestamp'], axis=1)

# %%
# Verify all columns in df_train_cleaned and df_test_cleaned are numeric
numeric_columns_train = df_train_cleaned.select_dtypes(include=[int, float]).columns
numeric_columns_test = df_test_cleaned.select_dtypes(include=[int, float]).columns

# %%
# Compute correlations only on numeric columns
df_train_corr = df_train_cleaned[numeric_columns_train].corr().abs().unstack().sort_values(kind="quicksort", ascending=False).reset_index()
df_train_corr.rename(columns={"level_0": "Feature 1", "level_1": "Feature 2", 0: 'Correlation Coefficient'}, inplace=True)
df_train_corr.drop(df_train_corr.iloc[1::2].index, inplace=True)
df_train_corr_nd = df_train_corr.drop(df_train_corr[df_train_corr['Correlation Coefficient'] == 1.0].index)

# %%
df_test_corr = df_test_cleaned[numeric_columns_test].corr().abs().unstack().sort_values(kind="quicksort", ascending=False).reset_index()
df_test_corr.rename(columns={"level_0": "Feature 1", "level_1": "Feature 2", 0: 'Correlation Coefficient'}, inplace=True)
df_test_corr.drop(df_test_corr.iloc[1::2].index, inplace=True)
df_test_corr_nd = df_test_corr.drop(df_test_corr[df_test_corr['Correlation Coefficient'] == 1.0].index)

# %%
# Training set high correlations
corr = df_train_corr_nd['Correlation Coefficient'] > 0.1
df_train_corr_nd[corr]
# Out:
#   Feature 1 Feature 2  Correlation Coefficient
# 6    lesson  day_part                    0.293
# 8    lesson   tool_id                    0.138

# %%
corr = df_test_corr_nd['Correlation Coefficient'] > 0.1
df_test_corr_nd[corr]
# Out:
#   Feature 1 Feature 2  Correlation Coefficient
# 6    lesson  day_part                    0.293
# 8    lesson   tool_id                    0.138

# %%
fig, axs = plt.subplots(nrows=2, figsize=(10, 10))

sns.heatmap(df_train.drop(['timestamp'], axis=1).corr(), ax=axs[0], annot=True, square=True, cmap='coolwarm', annot_kws={'size': 10})
sns.heatmap(df_test.drop(['timestamp'], axis=1).corr(), ax=axs[1], annot=True, square=True, cmap='coolwarm', annot_kws={'size': 10})

for i in range(2):
    axs[i].tick_params(axis='x', labelsize=7)
    axs[i].tick_params(axis='y', labelsize=7)

axs[0].set_title('Training Set Correlations', size=10)
axs[1].set_title('Test Set Correlations', size=10)

plt.show()

# %% [markdown]
# Lesson and Day_Part correlation Coefficient: -0.293
# There is a weak negative correlation between the lesson and day_part features. This means that as one feature's value increases, the other feature's value tends to decrease slightly. The relationship is not strong, suggesting other factors might influence these features.
#
#
# Lesson and Tool_ID correlation Coefficient: 0.138
# There is a very weak positive correlation between the lesson and tool_id features. This indicates a slight tendency for the values of these features to increase together, but the relationship is very weak and likely not significant. This suggests that lesson and tool_id are primarily independent of each other in terms of their linear relationship.
