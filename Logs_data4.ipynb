# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/deep/blob/main/Logs_data4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch

# %%
import pandas as pd

# %%
import torch
from torch import nn

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
CAD_path="/content/logs_CAD_2024_3_.xlsx"

# %%
data = pd.read_excel("/content/logs_CAD_2024_3_.xlsx")

# %%
display(pd.DataFrame(data))
# Out:
#        ID  Spec MotherTongue  Gender   Age  Activity  DayPart  Lesson  Grade
# 0   29292     1          est  female  20.0        23        3       1      5
# 1   26864     2          rus    male   NaN         7        3       0      0
# 2   26861     2          rus    male  21.0        18        1       1      3
# 3   26760     3          est  female   NaN         8        1       1      5
# 4   26544     4          est    male  21.0         9        1       1      5
# 5   29598    11          est    male  25.0         7        1       1      0
# 6   29133     1          est    male  20.0        14        1       1      5
# 7   26604     2          rus    male  23.0         6        1       1      4
# 8   29346     1          est    male  20.0         4        1       1      5
# 9   26563     4          est    male  21.0        14        1       1      4
# 10  26610     4          est    male  21.0         7        1       1      0
# 11  26789     3          est    male  22.0        12        2       0      0
# 12  29684     1          est    male   NaN         5        2       0      4
# 13  29723     1          est    male  20.0        14        1       1      4
# 14  29349     1          rus    male  26.0        13        3       1      4
# 15  29350     1          est    male  20.0         6        1       1      5
# 16  23558     4          est  female   NaN         7        3       0      0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['ID'].plot(kind='hist', bins=20, title='ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Spec'].plot(kind='hist', bins=20, title='Spec')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('MotherTongue').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='index', y='ID', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='ID', y='Spec', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Spec', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Age', y='Activity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['ID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('MotherTongue')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='MotherTongue', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('ID')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['ID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('ID')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Spec']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('MotherTongue')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='MotherTongue', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Spec')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Spec']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Spec')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['ID'].plot(kind='line', figsize=(8, 4), title='ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Spec'].plot(kind='line', figsize=(8, 4), title='Spec')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Gender'].value_counts()
#     for x_label, grp in _df_18.groupby('MotherTongue')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('MotherTongue')
# _ = plt.ylabel('Gender')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['MotherTongue'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='index', y='MotherTongue', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='index', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['MotherTongue'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='ID', y='MotherTongue', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='ID', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Settings

# %%
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
df = pd.read_excel("/content/logs_CAD_2024_3_.xlsx")
test_df = pd.read_excel("/content/logs_CAD_2024_3_.xlsx")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            17 non-null     int64
#  1   Spec          17 non-null     int64
#  2   MotherTongue  17 non-null     object
#  3   Gender        17 non-null     object
#  4   Age           13 non-null     float64
#  5   Activity      17 non-null     int64
#  6   DayPart       17 non-null     int64
#  7   Lesson        17 non-null     int64
#  8   Grade         17 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Features

# %%
def feature_logs(df):
     # Change Gender to numbers (male=1, female=0)
    df['Gender'] = df['Gender'].map({'male': 1, 'female': 0})

        # Limit numbers to those DayPart; other titles will be NaN
    df['DayPart'] = df['DayPart'].map({1: 1, 2: 2})

        # Change MotherTongue to numbers (est=1, rus=0)
    df['MotherTongue'] = df['MotherTongue'].map({'est': 1, 'rus': 0})


    return df

# %%
df = feature_logs(df) #Applay Features

# %% [markdown]
# Random sample of rows for checking

# %%
df.sample(n=5) #Random rows
# Out:
#        ID  Spec  MotherTongue  Gender    Age  Activity  DayPart  Lesson  Grade
# 10  26610     4             1       1 21.000         7    1.000       1      0
# 9   26563     4             1       1 21.000        14    1.000       1      4
# 8   29346     1             1       1 20.000         4    1.000       1      5
# 2   26861     2             0       1 21.000        18    1.000       1      3
# 1   26864     2             0       1    NaN         7      NaN       0      0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['ID'].plot(kind='hist', bins=20, title='ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Spec'].plot(kind='hist', bins=20, title='Spec')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['MotherTongue'].plot(kind='hist', bins=20, title='MotherTongue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='ID', y='Spec', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='Spec', y='MotherTongue', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='MotherTongue', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='Age', y='Activity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['ID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('Gender', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('ID')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Spec']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('Gender', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Spec')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['MotherTongue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('Gender', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('MotherTongue')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Gender']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('Gender', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Gender')
# _ = plt.ylabel('Age')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['ID'].plot(kind='line', figsize=(8, 4), title='ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['Spec'].plot(kind='line', figsize=(8, 4), title='Spec')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['MotherTongue'].plot(kind='line', figsize=(8, 4), title='MotherTongue')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Drop column

# %%
train_labels = df['Grade'].copy()
df = df.drop('Grade', axis=1)

# %%
df.describe(include=np.number)
# Out:
#              ID   Spec  MotherTongue  Gender    Age  Activity  DayPart  Lesson
# count    17.000 17.000        17.000  17.000 13.000    17.000   13.000  17.000
# mean  27801.647  2.706         0.765   0.824 21.538    10.235    1.154   0.765
# std    1758.647  2.469         0.437   0.393  1.984     5.166    0.376   0.437
# min   23558.000  1.000         0.000   0.000 20.000     4.000    1.000   0.000
# 25%   26610.000  1.000         1.000   1.000 20.000     7.000    1.000   1.000
# 50%   26864.000  2.000         1.000   1.000 21.000     8.000    1.000   1.000
# 75%   29349.000  4.000         1.000   1.000 22.000    14.000    1.000   1.000
# max   29723.000 11.000         1.000   1.000 26.000    23.000    2.000   1.000

# %% [markdown]
# Data clearning

# %%
df.isna().sum() #Columns with missing value
# Out:
# ID              0
# Spec            0
# MotherTongue    0
# Gender          0
# Age             4
# Activity        0
# DayPart         4
# Lesson          0
# dtype: int64

# %%
#Fill missing values with the modes
train_modes = df.mode().iloc[0]
train_modes
# Out:
# ID             23558.000
# Spec               1.000
# MotherTongue       1.000
# Gender             1.000
# Age               20.000
# Activity           7.000
# DayPart            1.000
# Lesson             1.000
# Name: 0, dtype: float64

# %%
def fill_missing(df, modes):
    df = df.fillna(modes)
    return df

df = fill_missing(df, train_modes)

# %%
df
# Out:
#        ID  Spec  MotherTongue  Gender    Age  Activity  DayPart  Lesson
# 0   29292     1             1       0 20.000        23    1.000       1
# 1   26864     2             0       1 20.000         7    1.000       0
# 2   26861     2             0       1 21.000        18    1.000       1
# 3   26760     3             1       0 20.000         8    1.000       1
# 4   26544     4             1       1 21.000         9    1.000       1
# 5   29598    11             1       1 25.000         7    1.000       1
# 6   29133     1             1       1 20.000        14    1.000       1
# 7   26604     2             0       1 23.000         6    1.000       1
# 8   29346     1             1       1 20.000         4    1.000       1
# 9   26563     4             1       1 21.000        14    1.000       1
# 10  26610     4             1       1 21.000         7    1.000       1
# 11  26789     3             1       1 22.000        12    2.000       0
# 12  29684     1             1       1 20.000         5    2.000       0
# 13  29723     1             1       1 20.000        14    1.000       1
# 14  29349     1             0       1 26.000        13    1.000       1
# 15  29350     1             1       1 20.000         6    1.000       1
# 16  23558     4             1       0 20.000         7    1.000       0

# %% [markdown]
# Min-max scaling

# %%
def scale_min_max(df, col_name, xmin, xmax):
    df[col_name] = (df[col_name] - xmin) / (xmax - xmin)
    return df

train_age_min = df['Age'].min()
train_age_max = df['Age'].max()
df = scale_min_max(df, 'Age', train_age_min, train_age_max)

df['Age'].describe()
# Out:
# count   17.000
# mean     0.196
# std      0.308
# min      0.000
# 25%      0.000
# 50%      0.000
# 75%      0.167
# max      1.000
# Name: Age, dtype: float64

# %% [markdown]
# Dummy variables addition:

# %%
def add_dummies(df, cols):
    df = pd.get_dummies(df, columns=cols)
    return df

cols = ['Activity', 'Gender', 'Spec', 'ID']
df = add_dummies(df, cols)

print(df.columns, '\n', len(df.columns))
# Out:
# Index(['MotherTongue', 'Age', 'DayPart', 'Lesson', 'Activity_4', 'Activity_5',
#        'Activity_6', 'Activity_7', 'Activity_8', 'Activity_9', 'Activity_12',
#        'Activity_13', 'Activity_14', 'Activity_18', 'Activity_23', 'Gender_0',
#        'Gender_1', 'Spec_1', 'Spec_2', 'Spec_3', 'Spec_4', 'Spec_11',
#        'ID_23558', 'ID_26544', 'ID_26563', 'ID_26604', 'ID_26610', 'ID_26760',
#        'ID_26789', 'ID_26861', 'ID_26864', 'ID_29133', 'ID_29292', 'ID_29346',
#        'ID_29349', 'ID_29350', 'ID_29598', 'ID_29684', 'ID_29723'],
#       dtype='object')
#  39

# %% [markdown]
# Data is procecced!

# %% [markdown]
# Data processing steps to the test set

# %%
test_proc = (test_df.pipe(feature_logs)
                    .drop(['DayPart', 'Lesson'], axis=1)
                    .pipe(fill_missing, train_modes)
                    .pipe(scale_min_max, 'Age', train_age_min, train_age_max)
                    .pipe(add_dummies, cols)
)

test_proc.sample(5)
# Out:
#     MotherTongue   Age  Grade  Activity_4  Activity_5  Activity_6  Activity_7  \
# 16             1 0.000      0       False       False       False        True
# 2              0 0.167      3       False       False       False       False
# 3              1 0.000      5       False       False       False       False
# 14             0 1.000      4       False       False       False       False
# 5              1 0.833      0       False       False       False        True
#
#     Activity_8  Activity_9  Activity_12  ...  ID_26861  ID_26864  ID_29133  \
# 16       False       False        False  ...     False     False     False
# 2        False       False        False  ...      True     False     False
# 3         True       False        False  ...     False     False     False
# 14       False       False        False  ...     False     False     False
# 5        False       False        False  ...     False     False     False
#
#     ID_29292  ID_29346  ID_29349  ID_29350  ID_29598  ID_29684  ID_29723
# 16     False     False     False     False     False     False     False
# 2      False     False     False     False     False     False     False
# 3      False     False     False     False     False     False     False
# 14     False     False      True     False     False     False     False
# 5      False     False     False     False      True     False     False
#
# [5 rows x 38 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_39['MotherTongue'].plot(kind='hist', bins=20, title='MotherTongue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['Grade'].plot(kind='hist', bins=20, title='Grade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_42.groupby('Activity_7').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_43.groupby('Activity_8').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_44.groupby('Activity_13').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_45.groupby('Activity_18').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_46.plot(kind='scatter', x='MotherTongue', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47.plot(kind='scatter', x='Age', y='Grade', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_48['MotherTongue'].plot(kind='line', figsize=(8, 4), title='MotherTongue')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50['Grade'].plot(kind='line', figsize=(8, 4), title='Grade')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_8'].value_counts()
#     for x_label, grp in _df_51.groupby('Activity_7')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_7')
# _ = plt.ylabel('Activity_8')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_13'].value_counts()
#     for x_label, grp in _df_52.groupby('Activity_8')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_8')
# _ = plt.ylabel('Activity_13')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_18'].value_counts()
#     for x_label, grp in _df_53.groupby('Activity_13')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_13')
# _ = plt.ylabel('Activity_18')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Gender_0'].value_counts()
#     for x_label, grp in _df_54.groupby('Activity_18')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_18')
# _ = plt.ylabel('Gender_0')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_55['Activity_7'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_55, x='MotherTongue', y='Activity_7', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_56['Activity_8'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_56, x='MotherTongue', y='Activity_8', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_57['Activity_13'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_57, x='MotherTongue', y='Activity_13', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_58['Activity_18'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_58, x='MotherTongue', y='Activity_18', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Model training

# %%
device = 'cuda' if torch.cuda.is_available() else 'gpu'
device
# Out:
# 'gpu'

# %%
train_modes = df.mode().iloc[0] #Fill missing values with the modes:
train_modes
# Out:
# MotherTongue        1
# Age             0.000
# DayPart         1.000
# Lesson              1
# Activity_4      False
# Activity_5      False
# Activity_6      False
# Activity_7      False
# Activity_8      False
# Activity_9      False
# Activity_12     False
# Activity_13     False
# Activity_14     False
# Activity_18     False
# Activity_23     False
# Gender_0        False
# Gender_1         True
# Spec_1          False
# Spec_2          False
# Spec_3          False
# Spec_4          False
# Spec_11         False
# ID_23558        False
# ID_26544        False
# ID_26563        False
# ID_26604        False
# ID_26610        False
# ID_26760        False
# ID_26789        False
# ID_26861        False
# ID_26864        False
# ID_29133        False
# ID_29292        False
# ID_29346        False
# ID_29349        False
# ID_29350        False
# ID_29598        False
# ID_29684        False
# ID_29723        False
# Name: 0, dtype: object

# %% [markdown]
# Remove colomns no need

# %%
df = df.drop(['Spec'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-434b5b73d866> in <cell line: 1>()
# ----> 1 df = df.drop(['Spec'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['Spec'] not found in axis"

# %%
df.sample(n=10)
# Out:
#     MotherTongue   Age  DayPart  Lesson  Activity_4  Activity_5  Activity_6  \
# 16             1 0.000    1.000       0       False       False       False
# 3              1 0.000    1.000       1       False       False       False
# 13             1 0.000    1.000       1       False       False       False
# 14             0 1.000    1.000       1       False       False       False
# 10             1 0.167    1.000       1       False       False       False
# 4              1 0.167    1.000       1       False       False       False
# 15             1 0.000    1.000       1       False       False        True
# 6              1 0.000    1.000       1       False       False       False
# 1              0 0.000    1.000       0       False       False       False
# 7              0 0.500    1.000       1       False       False        True
#
#     Activity_7  Activity_8  Activity_9  ...  ID_26861  ID_26864  ID_29133  \
# 16        True       False       False  ...     False     False     False
# 3        False        True       False  ...     False     False     False
# 13       False       False       False  ...     False     False     False
# 14       False       False       False  ...     False     False     False
# 10        True       False       False  ...     False     False     False
# 4        False       False        True  ...     False     False     False
# 15       False       False       False  ...     False     False     False
# 6        False       False       False  ...     False     False      True
# 1         True       False       False  ...     False      True     False
# 7        False       False       False  ...     False     False     False
#
#     ID_29292  ID_29346  ID_29349  ID_29350  ID_29598  ID_29684  ID_29723
# 16     False     False     False     False     False     False     False
# 3      False     False     False     False     False     False     False
# 13     False     False     False     False     False     False      True
# 14     False     False      True     False     False     False     False
# 10     False     False     False     False     False     False     False
# 4      False     False     False     False     False     False     False
# 15     False     False     False      True     False     False     False
# 6      False     False     False     False     False     False     False
# 1      False     False     False     False     False     False     False
# 7      False     False     False     False     False     False     False
#
# [10 rows x 39 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_59['MotherTongue'].plot(kind='hist', bins=20, title='MotherTongue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_60['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_61['Lesson'].plot(kind='hist', bins=20, title='Lesson')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_62.groupby('Activity_6').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_63.groupby('Activity_7').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_64.groupby('Activity_8').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_65.groupby('Activity_9').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_66.plot(kind='scatter', x='MotherTongue', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_67.plot(kind='scatter', x='Age', y='Lesson', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayPart']
#   ys = series['MotherTongue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_68.sort_values('DayPart', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Activity_6')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Activity_6', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayPart')
# _ = plt.ylabel('MotherTongue')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayPart']
#   ys = series['MotherTongue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_69.sort_values('DayPart', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Activity_7')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Activity_7', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayPart')
# _ = plt.ylabel('MotherTongue')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayPart']
#   ys = series['MotherTongue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_70.sort_values('DayPart', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Activity_8')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Activity_8', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayPart')
# _ = plt.ylabel('MotherTongue')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DayPart']
#   ys = series['MotherTongue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_71.sort_values('DayPart', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Activity_9')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Activity_9', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DayPart')
# _ = plt.ylabel('MotherTongue')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_72['MotherTongue'].plot(kind='line', figsize=(8, 4), title='MotherTongue')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_73['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_74['Lesson'].plot(kind='line', figsize=(8, 4), title='Lesson')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_7'].value_counts()
#     for x_label, grp in _df_75.groupby('Activity_6')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_6')
# _ = plt.ylabel('Activity_7')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_8'].value_counts()
#     for x_label, grp in _df_76.groupby('Activity_7')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_7')
# _ = plt.ylabel('Activity_8')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_9'].value_counts()
#     for x_label, grp in _df_77.groupby('Activity_8')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_8')
# _ = plt.ylabel('Activity_9')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Activity_13'].value_counts()
#     for x_label, grp in _df_78.groupby('Activity_9')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Activity_9')
# _ = plt.ylabel('Activity_13')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_79['Activity_6'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_79, x='MotherTongue', y='Activity_6', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_80['Activity_7'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_80, x='MotherTongue', y='Activity_7', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_81['Activity_8'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_81, x='MotherTongue', y='Activity_8', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_82['Activity_9'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_82, x='MotherTongue', y='Activity_9', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
