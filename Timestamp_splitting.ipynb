# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/deep/blob/main/Timestamp_splitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import torch

# Load the Excel file into a DataFrame
df = pd.read_excel('/content/logs_AutoCADc_20240629-KTJ_exc.xlsx')

# Assuming the timestamp is in the first column, adjust if necessary
timestamp_col = df.columns[0]

# Define a function to split the timestamp into date and time
def split_timestamp(timestamp):
    # Ensure the input is a datetime object
    if isinstance(timestamp, str):
        timestamp = pd.to_datetime(timestamp)
    date = timestamp.date()
    time = timestamp.time()
    return date, time

# Apply the function to split the timestamps
split_data = df[timestamp_col].apply(lambda x: split_timestamp(x))

# Create separate columns for date and time
df['Date'] = split_data.apply(lambda x: x[0])
df['Time'] = split_data.apply(lambda x: x[1])

# Drop the original timestamp column if needed
df = df.drop(columns=[timestamp_col])

# Save the new DataFrame to a new Excel file
df.to_excel('output.xlsx', index=False)

print("Timestamp data has been separated and saved to 'output.xlsx'")
# Out:
# Timestamp data has been separated and saved to 'output.xlsx'

# %%
file_path = '/content/output.xlsx' # Data from Excel
data = pd.read_excel(file_path)

# %%
display(pd.DataFrame(data))
# Out:
#             Date      Time
# 0     2024-06-20  07:10:47
# 1     2024-06-20  07:10:47
# 2     2024-06-20  07:10:38
# 3     2024-06-20  07:07:47
# 4     2024-06-20  07:07:46
# ...          ...       ...
# 11929 2023-06-09  10:39:04
# 11930 2023-06-09  10:38:15
# 11931 2023-06-09  10:38:13
# 11932 2023-06-09  10:38:09
# 11933 2023-06-09  10:38:08
#
# [11934 rows x 2 columns]
