# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/deep/blob/main/Logs_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch

# %%
import pandas as pd

# %%
CAD_path="/content/logs_CAD_2024_1.xlsx"

# %% [markdown]
# CAD_logs file data

# %%
data = pd.read_excel("/content/logs_CAD_2024_1.xlsx")

# %%
display(pd.DataFrame(data))
# Out:
#                timestamp  user_id  tool_id  log_count  lesson  day_part
# 0     15/04/24, 11:37:03    26861   233243        3.0       0         1
# 1     15/04/24, 11:37:03    26861   233243        0.0       0         1
# 2     15/04/24, 11:37:03    26861   233243        0.0       0         1
# 3     15/04/24, 11:30:50    26861     2949        1.0       0         1
# 4     15/04/24, 11:30:37    26861   244208        3.0       0         1
# ...                  ...      ...      ...        ...     ...       ...
# 6091   1/02/24, 20:00:42    29349     2949        0.0       0         3
# 6092  29/01/24, 19:00:53    29349     2949        0.0       0         3
# 6093  29/01/24, 19:00:52    29349     2949        0.0       0         3
# 6094  29/01/24, 19:00:52    29349     2949        0.0       0         3
# 6095  29/01/24, 19:00:52    29349     2949        0.0       0         3
#
# [6096 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
_df_0['user_id'].plot(kind='hist', bins=20, title='user_id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='log_count', y='lesson', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Users activitiy

# %%
from matplotlib import pyplot as plt
_df_1['user_id'].plot(kind='hist', bins=20, title='user_id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# log_count vs tool_id

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='tool_id', y='log_count', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# log_count vs timestamp

# %%
from matplotlib import pyplot as plt
import seaborn as snsimestamp vs log_count
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['timestamp']
  ys = series['log_count']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('timestamp', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('timestamp')
_ = plt.ylabel('log_count')

# %%
# @title log_count

from matplotlib import pyplot as plt
data['log_count'].plot(kind='line', figsize=(8, 4), title='log_count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Convert to excel file

# %%
d.to_excel("output_lesson.xlsx") #see file in sample data, refresh and download
